# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-lugtay22 because the default path (/home/mde/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
x = np.arange(-5, 5, 0.01)
k1 = 1
k2 = 3

# %%
plt.figure(figsize=(15, 10))
plt.plot(x, np.cos(k1*x), x, np.cos(k2*x))
plt.show()
